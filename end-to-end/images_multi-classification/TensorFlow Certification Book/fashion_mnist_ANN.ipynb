# %% [markdown]
# ## Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt #helper libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
from pathlib import Path

src_dir = Path('/content/drive/MyDrive/python_library/') # the path of the directory which saves your .py file

import sys
try:
  sys.path.index(str(src_dir))
except ValueError:
  sys.path.insert(0,str(src_dir))

sys.path # print system path
import tensorflow_keras_library as ezkeras
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Code

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
#class_names=['Top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankleboot']

# %%
#show_initial_images(X_train, y_train, class_names)

# %%
#X_train.shape

# %%
X_train, input_shape = ezkeras.prepare_np_for_ANN(X_train)
X_test, input_shape = ezkeras.prepare_np_for_ANN(X_test)
#X_train.shape
# Out:
# 3
# 3

# %%
y_train.shape
# Out:
# (60000,)

# %%
base_model = ezkeras.build_ANN(input_shape, [64])
base_model, history = ezkeras.run_model(base_model, X_train, y_train, outputs=10, epochs=50, verbose=1)
# Out:
# 64 0
# settings:  softmax sparse_categorical_crossentropy adam accuracy
# Epoch 1/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 19.6475 - accuracy: 0.7594
# Epoch 2/50
# 1875/1875 [==============================] - 7s 3ms/step - loss: 3.6223 - accuracy: 0.7909
# Epoch 3/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.4806 - accuracy: 0.7879
# Epoch 4/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4848 - accuracy: 0.7782
# Epoch 5/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.4086 - accuracy: 0.7810
# Epoch 6/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 1.2282 - accuracy: 0.7810
# Epoch 7/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.1573 - accuracy: 0.7852
# Epoch 8/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 1.1304 - accuracy: 0.7885
# Epoch 9/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.0459 - accuracy: 0.7893
# Epoch 10/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.0162 - accuracy: 0.7929
# Epoch 11/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.9915 - accuracy: 0.7931
# Epoch 12/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9578 - accuracy: 0.7948
# Epoch 13/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9445 - accuracy: 0.7989
# Epoch 14/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.9503 - accuracy: 0.7964
# Epoch 15/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9397 - accuracy: 0.7973
# Epoch 16/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9352 - accuracy: 0.7992
# Epoch 17/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.8918 - accuracy: 0.8023
# Epoch 18/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9212 - accuracy: 0.8021
# Epoch 19/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9187 - accuracy: 0.8026
# Epoch 20/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.8780 - accuracy: 0.8037
# Epoch 21/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.9122 - accuracy: 0.8019
# Epoch 22/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8735 - accuracy: 0.8071
# Epoch 23/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.9122 - accuracy: 0.8030
# Epoch 24/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.8954 - accuracy: 0.8062
# Epoch 25/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8648 - accuracy: 0.8065
# Epoch 26/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.8833 - accuracy: 0.8040
# Epoch 27/50
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9054 - accuracy: 0.8043
# Epoch 28/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.9091 - accuracy: 0.8056
# Epoch 29/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.8926 - accuracy: 0.8060
