# %%
import tensorflow as tf
print(tf.__version__)
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Conv2D, Dense, Flatten, Dropout, GlobalMaxPooling2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.models import Model
# Out:
# 2.14.0

# %% [markdown]
# ## Load Data

# %%
cifar10 = tf.keras.datasets.cifar10

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ## Analyze Data

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000, 1)

# %%
# Notice the labels are in a 1 dimensional array
# Fix this as the labels must either be scalar or one-hot encoded
y_train = y_train.flatten()
y_test = y_test.flatten()
y_train.shape
# Out:
# (50000,)

# %%
# Now the labels are scalar
y_train[0]
# Out:
# 6

# %%
# number of classes
K = len(set(y_train))
print("number of classes:", K)
# Out:
# number of classes: 10

# %%
# label mapping
labels = '''airplane
automobile
bird
cat
deer
dog
frog
horse
ship
truck'''.split()

# %%
plt.title(labels[y_train[0]])
plt.imshow(x_train[0])

# %% [markdown]
# ## Numericize Data

# %%
x_train[0]
# Out:
# array([[[ 59,  62,  63],
#         [ 43,  46,  45],
#         [ 50,  48,  43],
#         ...,
#         [158, 132, 108],
#         [152, 125, 102],
#         [148, 124, 103]],
#
#        [[ 16,  20,  20],
#         [  0,   0,   0],
#         [ 18,   8,   0],
#         ...,
#         [123,  88,  55],
#         [119,  83,  50],
#         [122,  87,  57]],
#
#        [[ 25,  24,  21],
#         [ 16,   7,   0],
#         [ 49,  27,   8],
#         ...,
#         [118,  84,  50],
#         [120,  84,  50],
#         [109,  73,  42]],
#
#        ...,
#
#        [[208, 170,  96],
#         [201, 153,  34],
#         [198, 161,  26],
#         ...,
#         [160, 133,  70],
#         [ 56,  31,   7],
#         [ 53,  34,  20]],
#
#        [[180, 139,  96],
#         [173, 123,  42],
#         [186, 144,  30],
#         ...,
#         [184, 148,  94],
#         [ 97,  62,  34],
#         [ 83,  53,  34]],
#
#        [[177, 144, 116],
#         [168, 129,  94],
#         [179, 142,  87],
#         ...,
#         [216, 184, 140],
#         [151, 118,  84],
#         [123,  92,  72]]], dtype=uint8)

# %%
x_train = x_train.astype(float)/255.0
x_test = x_test.astype(float)/255.0

# %%
x_train[0]
# Out:
# array([[[0.23137255, 0.24313725, 0.24705882],
#         [0.16862745, 0.18039216, 0.17647059],
#         [0.19607843, 0.18823529, 0.16862745],
#         ...,
#         [0.61960784, 0.51764706, 0.42352941],
#         [0.59607843, 0.49019608, 0.4       ],
#         [0.58039216, 0.48627451, 0.40392157]],
#
#        [[0.0627451 , 0.07843137, 0.07843137],
#         [0.        , 0.        , 0.        ],
#         [0.07058824, 0.03137255, 0.        ],
#         ...,
#         [0.48235294, 0.34509804, 0.21568627],
#         [0.46666667, 0.3254902 , 0.19607843],
#         [0.47843137, 0.34117647, 0.22352941]],
#
#        [[0.09803922, 0.09411765, 0.08235294],
#         [0.0627451 , 0.02745098, 0.        ],
#         [0.19215686, 0.10588235, 0.03137255],
#         ...,
#         [0.4627451 , 0.32941176, 0.19607843],
#         [0.47058824, 0.32941176, 0.19607843],
#         [0.42745098, 0.28627451, 0.16470588]],
#
#        ...,
#
#        [[0.81568627, 0.66666667, 0.37647059],
#         [0.78823529, 0.6       , 0.13333333],
#         [0.77647059, 0.63137255, 0.10196078],
#         ...,
#         [0.62745098, 0.52156863, 0.2745098 ],
#         [0.21960784, 0.12156863, 0.02745098],
#         [0.20784314, 0.13333333, 0.07843137]],
#
#        [[0.70588235, 0.54509804, 0.37647059],
#         [0.67843137, 0.48235294, 0.16470588],
#         [0.72941176, 0.56470588, 0.11764706],
#         ...,
#         [0.72156863, 0.58039216, 0.36862745],
#         [0.38039216, 0.24313725, 0.13333333],
#         [0.3254902 , 0.20784314, 0.13333333]],
#
#        [[0.69411765, 0.56470588, 0.45490196],
#         [0.65882353, 0.50588235, 0.36862745],
#         [0.70196078, 0.55686275, 0.34117647],
#         ...,
#         [0.84705882, 0.72156863, 0.54901961],
#         [0.59215686, 0.4627451 , 0.32941176],
#         [0.48235294, 0.36078431, 0.28235294]]])

# %% [markdown]
# ## Build the Model

# %%
# Build the model using the functional API
i = Input(shape=x_train[0].shape)
# x = Conv2D(32, (3, 3), strides=2, activation='relu')(i)
# x = Conv2D(64, (3, 3), strides=2, activation='relu')(x)
# x = Conv2D(128, (3, 3), strides=2, activation='relu')(x)

# Notice multiple Conv2D without strides with a single MaxPooling after the two Conv2D
# Also notice batch normalization layers after each Conv2D
x = Conv2D(32, (3, 3), activation='relu', padding='same')(i)
x = BatchNormalization()(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.2)(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.2)(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2))(x)
# x = Dropout(0.2)(x)

# x = GlobalMaxPooling2D()(x)
x = Flatten()(x)
x = Dropout(0.2)(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(K, activation='softmax')(x)

model = Model(i, x)
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Add data augmentation
batch_size = 32
# create data generator
data_generator = tf.keras.preprocessing.image.ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
# create a training generator from the data generator
train_generator = data_generator.flow(x_train, y_train, batch_size)
steps_per_epoch = x_train.shape[0] // batch_size
r = model.fit(train_generator, validation_data=(x_test, y_test), steps_per_epoch=steps_per_epoch, epochs=50)
# Out:
# Epoch 1/50
# 1562/1562 [==============================] - 60s 28ms/step - loss: 1.4259 - accuracy: 0.5034 - val_loss: 1.1288 - val_accuracy: 0.6046
# Epoch 2/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.9878 - accuracy: 0.6560 - val_loss: 0.8163 - val_accuracy: 0.7113
# Epoch 3/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.8409 - accuracy: 0.7117 - val_loss: 0.8100 - val_accuracy: 0.7325
# Epoch 4/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.7412 - accuracy: 0.7471 - val_loss: 0.9191 - val_accuracy: 0.7124
# Epoch 5/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.6781 - accuracy: 0.7689 - val_loss: 0.6885 - val_accuracy: 0.7680
# Epoch 6/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.6287 - accuracy: 0.7857 - val_loss: 0.6635 - val_accuracy: 0.7833
# Epoch 7/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.5838 - accuracy: 0.8039 - val_loss: 0.5505 - val_accuracy: 0.8161
# Epoch 8/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.5456 - accuracy: 0.8153 - val_loss: 0.5669 - val_accuracy: 0.8101
# Epoch 9/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.5205 - accuracy: 0.8227 - val_loss: 0.5699 - val_accuracy: 0.8135
# Epoch 10/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.4869 - accuracy: 0.8361 - val_loss: 0.5053 - val_accuracy: 0.8302
# Epoch 11/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.4755 - accuracy: 0.8385 - val_loss: 0.5204 - val_accuracy: 0.8224
# Epoch 12/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.4422 - accuracy: 0.8490 - val_loss: 0.5093 - val_accuracy: 0.8280
# Epoch 13/50
# 1562/1562 [==============================] - 41s 26ms/step - loss: 0.4269 - accuracy: 0.8544 - val_loss: 0.5223 - val_accuracy: 0.8249
# Epoch 14/50
# 1562/1562 [==============================] - 39s 25ms/step - loss: 0.3977 - accuracy: 0.8632 - val_loss: 0.4672 - val_accuracy: 0.8454
# Epoch 15/50
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3902 - accuracy: 0.8671 - val_loss: 0.4166 - val_accuracy: 0.8616
# Epoch 16/50
# 1562/1562 [==============================] - 40s 26ms/step - loss: 0.3764 - accuracy: 0.8707 - val_loss: 0.4368 - val_accuracy: 0.8565
# Epoch 17/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.3593 - accuracy: 0.8780 - val_loss: 0.4786 - val_accuracy: 0.8403
# Epoch 18/50
# 1562/1562 [==============================] - 39s 25ms/step - loss: 0.3492 - accuracy: 0.8794 - val_loss: 0.4736 - val_accuracy: 0.8487
# Epoch 19/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.3344 - accuracy: 0.8853 - val_loss: 0.4760 - val_accuracy: 0.8503
# Epoch 20/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.3273 - accuracy: 0.8873 - val_loss: 0.4477 - val_accuracy: 0.8550
# Epoch 21/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.3132 - accuracy: 0.8924 - val_loss: 0.4134 - val_accuracy: 0.8643
# Epoch 22/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.3113 - accuracy: 0.8935 - val_loss: 0.4007 - val_accuracy: 0.8707
# Epoch 23/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.2967 - accuracy: 0.8981 - val_loss: 0.3990 - val_accuracy: 0.8692
# Epoch 24/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.2897 - accuracy: 0.9009 - val_loss: 0.3937 - val_accuracy: 0.8775
# Epoch 25/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.2790 - accuracy: 0.9034 - val_loss: 0.4063 - val_accuracy: 0.8688
# Epoch 26/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2728 - accuracy: 0.9061 - val_loss: 0.4599 - val_accuracy: 0.8519
# Epoch 27/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2725 - accuracy: 0.9062 - val_loss: 0.3926 - val_accuracy: 0.8740
# Epoch 28/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.2660 - accuracy: 0.9086 - val_loss: 0.3834 - val_accuracy: 0.8760
# Epoch 29/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2512 - accuracy: 0.9139 - val_loss: 0.3837 - val_accuracy: 0.8785
# Epoch 30/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2556 - accuracy: 0.9114 - val_loss: 0.3833 - val_accuracy: 0.8792
# Epoch 31/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.2412 - accuracy: 0.9159 - val_loss: 0.4283 - val_accuracy: 0.8686
# Epoch 32/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.2375 - accuracy: 0.9184 - val_loss: 0.4000 - val_accuracy: 0.8712
# Epoch 33/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2384 - accuracy: 0.9187 - val_loss: 0.3969 - val_accuracy: 0.8697
# Epoch 34/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.2299 - accuracy: 0.9199 - val_loss: 0.3942 - val_accuracy: 0.8776
# Epoch 35/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.2216 - accuracy: 0.9242 - val_loss: 0.4181 - val_accuracy: 0.8752
# Epoch 36/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.2245 - accuracy: 0.9223 - val_loss: 0.4362 - val_accuracy: 0.8679
# Epoch 37/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.2185 - accuracy: 0.9257 - val_loss: 0.4099 - val_accuracy: 0.8725
# Epoch 38/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.2177 - accuracy: 0.9242 - val_loss: 0.4284 - val_accuracy: 0.8754
# Epoch 39/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2122 - accuracy: 0.9269 - val_loss: 0.3744 - val_accuracy: 0.8783
# Epoch 40/50
# 1562/1562 [==============================] - 42s 27ms/step - loss: 0.2066 - accuracy: 0.9292 - val_loss: 0.4008 - val_accuracy: 0.8827
# Epoch 41/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.2009 - accuracy: 0.9302 - val_loss: 0.4112 - val_accuracy: 0.8781
# Epoch 42/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.2050 - accuracy: 0.9299 - val_loss: 0.4067 - val_accuracy: 0.8796
# Epoch 43/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.1939 - accuracy: 0.9335 - val_loss: 0.3861 - val_accuracy: 0.8768
# Epoch 44/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.1939 - accuracy: 0.9335 - val_loss: 0.3968 - val_accuracy: 0.8848
# Epoch 45/50
# 1562/1562 [==============================] - 43s 28ms/step - loss: 0.1920 - accuracy: 0.9342 - val_loss: 0.3917 - val_accuracy: 0.8776
# Epoch 46/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1916 - accuracy: 0.9345 - val_loss: 0.4346 - val_accuracy: 0.8755
# Epoch 47/50
# 1562/1562 [==============================] - 45s 29ms/step - loss: 0.1898 - accuracy: 0.9349 - val_loss: 0.4372 - val_accuracy: 0.8773
# Epoch 48/50
# 1562/1562 [==============================] - 44s 28ms/step - loss: 0.1852 - accuracy: 0.9364 - val_loss: 0.3956 - val_accuracy: 0.8856
# Epoch 49/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.1859 - accuracy: 0.9357 - val_loss: 0.4200 - val_accuracy: 0.8877
# Epoch 50/50
# 1562/1562 [==============================] - 43s 27ms/step - loss: 0.1804 - accuracy: 0.9382 - val_loss: 0.4328 - val_accuracy: 0.8769

# %% [markdown]
# ## Analyze the Model

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
# Plot confusion matrix
from sklearn.metrics import confusion_matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
  """
  This function prints and plots the confusion matrix.
  Normalization can be applied by setting `normalize=True`.
  """
  if normalize:
      cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
      print("Normalized confusion matrix")
  else:
      print('Confusion matrix, without normalization')

  print(cm)

  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(classes))
  plt.xticks(tick_marks, classes, rotation=45)
  plt.yticks(tick_marks, classes)

  fmt = '.2f' if normalize else 'd'
  thresh = cm.max() / 2.
  for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
      plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  plt.show()


p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Confusion matrix, without normalization
# [[891   8  20  15   5   4  10   6  22  19]
#  [  2 950   1   2   0   0   3   0   7  35]
#  [ 38   0 807  33  27  23  58   8   3   3]
#  [ 11   2  23 754  35  89  63  10   2  11]
#  [  6   1  30  22 860  16  50  11   2   2]
#  [  4   1  11 101  27 820  25   9   0   2]
#  [  4   3  14  18   5   1 951   0   4   0]
#  [  6   0  19  21  27  35   9 876   5   2]
#  [ 26  10   4   7   4   0   4   0 921  24]
#  [  7  39   2   5   0   1   2   1   4 939]]

# %%
misclassified_idx = np.where(p_test != y_test)[0]
i = np.random.choice(misclassified_idx)
plt.imshow(x_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[y_test[i]], labels[p_test[i]]));
