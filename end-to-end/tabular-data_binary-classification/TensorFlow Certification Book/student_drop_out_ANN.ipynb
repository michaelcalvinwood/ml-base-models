# %% [markdown]
# ## Import Libraries

# %%
# import tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
print(tf.__version__)
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, LabelEncoder
from sklearn.preprocessing import StandardScaler

import pandas as pd
# Out:
# 2.14.0

# %%
from google.colab import drive
drive.mount('/content/drive')
from pathlib import Path

src_dir = Path('/content/drive/MyDrive/python_library/') # the path of the directory which saves your .py file

import sys
try:
  sys.path.index(str(src_dir))
except ValueError:
  sys.path.insert(0,str(src_dir))

sys.path # print system path
from tensorflow_keras_library import build_ANN, run_model, get_value_prediction, prepare_df_for_ANN
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Code: Data Set #1

# %%
df = pd.read_csv('https://ml-datasets.nyc3.digitaloceanspaces.com/tabular-data_binary-classification/student-drop-out.csv')

# %%
df.head()

# %%
X_train, X_test, y_train, y_test, input_shape = prepare_df_for_ANN(df, ['Library', 'Resources', 'Finance', 'Scholarships', 'Study Time', 'Study Group', 'GPA', 'Test'], ['Graduated'])

# %%
#X_train.head()

# %%
#y_train.head()

# %%
base_model = build_ANN(input_shape, [32])
base_model, history = run_model(base_model, X_train, y_train, outputs=2, epochs=300, verbose=1)

# %% [markdown]
# ## Code: Data Set #2

# %%
df = pd.read_csv('https://ml-datasets.nyc3.digitaloceanspaces.com/tabular-data_binary-classification/Students-Dropout-Prediction.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  access  tests tests_grade  exam  project project_grade  \
# 0           0    1256  57.00           A  19.0    91.54             A
# 1           1     985  42.87           B  19.0    75.96             A
# 2           2    1455  54.50           A  16.0    96.79             A
# 3           3     998  54.50           A  16.0    93.36             A
# 4           4    1347  55.00           A  16.0    92.86             A
#
#    assignments  result_points result_grade  graduate  year  acad_year
# 0         40.0         189.92            A         1  2019  2019/2020
# 1         13.7         189.43            A         1  2017  2017/2018
# 2         40.0         188.91            A         1  2019  2019/2020
# 3         40.0         186.85            A         1  2019  2019/2020
# 4         39.0         186.38            A         1  2019  2019/2020

# %%
X_train, X_test, y_train, y_test, input_shape = prepare_df_for_ANN(df, ['access', 'tests', 'tests_grade', 'exam', 'project', 'project_grade', 'assignments', 'result_points', 'result_grade'], ['graduate'])

# %%
base_model1 = build_ANN(input_shape, [32])
base_model1, history = run_model(base_model1, X_train, y_train, outputs=2, epochs=300, verbose=1)
# Out:
# 32 0
# settings:  sigmoid binary_crossentropy adam accuracy
# Epoch 1/300
# 8/8 [==============================] - 1s 4ms/step - loss: 0.7873 - accuracy: 0.5625
# Epoch 2/300
# 8/8 [==============================] - 0s 5ms/step - loss: 0.6395 - accuracy: 0.7891
# Epoch 3/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5417 - accuracy: 0.7891
# Epoch 4/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.4735 - accuracy: 0.7891
# Epoch 5/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.7891
# Epoch 6/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3753 - accuracy: 0.7891
# Epoch 7/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3370 - accuracy: 0.7891
# Epoch 8/300
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3002 - accuracy: 0.7891
# Epoch 9/300
# 8/8 [==============================] - 0s 4ms/step - loss: 0.2710 - accuracy: 0.8086
# Epoch 10/300
# ...
