# %%
import numpy as np
from sklearn.datasets import load_iris
iris = load_iris()

X = iris.data # numpy array with sepal measurements
y = iris.target # the three classes of irises (array values between 0-2)

# transform y using one hot encoding
# e.g. class 0 --> [1, 0, 0] class 1 --> [0, 1, 0] class 2 --> [0, 0, 1]
from keras.utils import to_categorical
y = to_categorical(y)

# create the training tuple
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# scale the values so they all fit within a range (usually between 0 and 1) to help the neural network avoid large biases
from sklearn.preprocessing import MinMaxScaler
scaler_object = MinMaxScaler()
scaler_object.fit(X_train)
scaled_X_train = scaler_object.transform(X_train)
scaled_X_test = scaler_object.transform(X_test)

from keras.models import Sequential
from keras.layers import Dense

print('scaled_X_train shape', scaled_X_train.shape)
print('scaled_X_train value', scaled_X_train[0])

model = Sequential()
model.add(Dense(8, input_dim=4, activation='relu'))
model.add(Dense(8, input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax')) # the final Dense layer has three nodes (one for each class of iris) with the softmax selecting which of the three it is
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()

model.fit(scaled_X_train,y_train,epochs=150, verbose=1)

from sklearn.metrics import confusion_matrix,classification_report
predict_x = model.predict(scaled_X_test)
classes_x=np.argmax(predict_x,axis=1)

print('confusion matrix', confusion_matrix(y_test.argmax(axis=1),classes_x))
print('classification report', classification_report(y_test.argmax(axis=1),classes_x))

model.save('irisClassificationModel.h5')

from keras.models import load_model

loaded_model = load_model('irisClassificationModel.h5')

print('loaded model test')
predict_x = loaded_model.predict(scaled_X_test)
classes_x=np.argmax(predict_x,axis=1)

print('loaded confusion matrix', confusion_matrix(y_test.argmax(axis=1),classes_x))
print('loaded classification report', classification_report(y_test.argmax(axis=1),classes_x))
# Out:
# scaled_X_train shape (100, 4)
# scaled_X_train value [0.41176471 0.40909091 0.55357143 0.5       ]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 40
#
#  dense_1 (Dense)             (None, 8)                 72
#
#  dense_2 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 139 (556.00 Byte)
# Trainable params: 139 (556.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/150
# 4/4 [==============================] - 2s 9ms/step - loss: 1.0938 - accuracy: 0.3400
# Epoch 2/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0884 - accuracy: 0.3400
# Epoch 3/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0844 - accuracy: 0.3400
# Epoch 4/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0806 - accuracy: 0.3400
# Epoch 5/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0767 - accuracy: 0.3400
# Epoch 6/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0724 - accuracy: 0.3400
# Epoch 7/150
# 4/4 [==============================] - 0s 6ms/step - loss: 1.0680 - accuracy: 0.3400
# Epoch 8/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0633 - accuracy: 0.3400
# Epoch 9/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0593 - accuracy: 0.3500
# Epoch 10/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0548 - accuracy: 0.3500
# Epoch 11/150
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0506 - accuracy: 0.3400
# Epoch 12/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0462 - accuracy: 0.3400
# Epoch 13/150
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0418 - accuracy: 0.3400
# Epoch 14/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0371 - accuracy: 0.3400
# Epoch 15/150
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0324 - accuracy: 0.3400
# Epoch 16/150
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0276 - accuracy: 0.3900
# Epoch 17/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0226 - accuracy: 0.4300
# Epoch 18/150
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0172 - accuracy: 0.4600
# Epoch 19/150
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0107 - accuracy: 0.5100
# Epoch 20/150
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0032 - accuracy: 0.5400
# Epoch 21/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9935 - accuracy: 0.5500
# Epoch 22/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9824 - accuracy: 0.5700
# Epoch 23/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9716 - accuracy: 0.5800
# Epoch 24/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9608 - accuracy: 0.6000
# Epoch 25/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9515 - accuracy: 0.6000
# Epoch 26/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9425 - accuracy: 0.6300
# Epoch 27/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9335 - accuracy: 0.6400
# Epoch 28/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9247 - accuracy: 0.6400
# Epoch 29/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9160 - accuracy: 0.6400
# Epoch 30/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.9076 - accuracy: 0.6400
# Epoch 31/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.8991 - accuracy: 0.6400
# Epoch 32/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8904 - accuracy: 0.6400
# Epoch 33/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8825 - accuracy: 0.6400
# Epoch 34/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8736 - accuracy: 0.6400
# Epoch 35/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8655 - accuracy: 0.6400
# Epoch 36/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8566 - accuracy: 0.6400
# Epoch 37/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8480 - accuracy: 0.6400
# Epoch 38/150
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8397 - accuracy: 0.6400
# Epoch 39/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8319 - accuracy: 0.6400
# Epoch 40/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.8249 - accuracy: 0.6400
# Epoch 41/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8174 - accuracy: 0.6400
# Epoch 42/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8096 - accuracy: 0.6400
# Epoch 43/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8013 - accuracy: 0.6400
# Epoch 44/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7931 - accuracy: 0.6400
# Epoch 45/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7851 - accuracy: 0.6400
# Epoch 46/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7764 - accuracy: 0.6400
# Epoch 47/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7682 - accuracy: 0.6500
# Epoch 48/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7594 - accuracy: 0.6500
# Epoch 49/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7505 - accuracy: 0.6500
# Epoch 50/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7414 - accuracy: 0.6500
# Epoch 51/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7330 - accuracy: 0.6500
# Epoch 52/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7240 - accuracy: 0.6500
# Epoch 53/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7150 - accuracy: 0.6500
# Epoch 54/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.7062 - accuracy: 0.6500
# Epoch 55/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6974 - accuracy: 0.6500
# Epoch 56/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6884 - accuracy: 0.6500
# Epoch 57/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6792 - accuracy: 0.6500
# Epoch 58/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6704 - accuracy: 0.6500
# Epoch 59/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6614 - accuracy: 0.6500
# Epoch 60/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.6527 - accuracy: 0.6500
# Epoch 61/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6442 - accuracy: 0.6500
# Epoch 62/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6365 - accuracy: 0.6500
# Epoch 63/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6284 - accuracy: 0.6500
# Epoch 64/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6204 - accuracy: 0.6500
# Epoch 65/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6125 - accuracy: 0.6600
# Epoch 66/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.6045 - accuracy: 0.6700
# Epoch 67/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5969 - accuracy: 0.6700
# Epoch 68/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5895 - accuracy: 0.6700
# Epoch 69/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5823 - accuracy: 0.6700
# Epoch 70/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5755 - accuracy: 0.6700
# Epoch 71/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5692 - accuracy: 0.6700
# Epoch 72/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5634 - accuracy: 0.6700
# Epoch 73/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5576 - accuracy: 0.6700
# Epoch 74/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5519 - accuracy: 0.6700
# Epoch 75/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5459 - accuracy: 0.6900
# Epoch 76/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5404 - accuracy: 0.6900
# Epoch 77/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5348 - accuracy: 0.7000
# Epoch 78/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.5295 - accuracy: 0.7000
# Epoch 79/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5245 - accuracy: 0.7000
# Epoch 80/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5197 - accuracy: 0.7000
# Epoch 81/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5151 - accuracy: 0.7100
# Epoch 82/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.5104 - accuracy: 0.7000
# Epoch 83/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5059 - accuracy: 0.7100
# Epoch 84/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.5015 - accuracy: 0.7100
# Epoch 85/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4978 - accuracy: 0.7100
# Epoch 86/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4938 - accuracy: 0.7500
# Epoch 87/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4896 - accuracy: 0.7600
# Epoch 88/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4857 - accuracy: 0.7700
# Epoch 89/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4820 - accuracy: 0.7800
# Epoch 90/150
# 4/4 [==============================] - 0s 20ms/step - loss: 0.4782 - accuracy: 0.7900
# Epoch 91/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4744 - accuracy: 0.8000
# Epoch 92/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4709 - accuracy: 0.8200
# Epoch 93/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.4674 - accuracy: 0.8300
# Epoch 94/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4640 - accuracy: 0.8300
# Epoch 95/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4607 - accuracy: 0.8300
# Epoch 96/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4576 - accuracy: 0.8100
# Epoch 97/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4543 - accuracy: 0.8200
# Epoch 98/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4513 - accuracy: 0.8500
# Epoch 99/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4479 - accuracy: 0.8800
# Epoch 100/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4450 - accuracy: 0.8800
# Epoch 101/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4421 - accuracy: 0.8800
# Epoch 102/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4392 - accuracy: 0.8800
# Epoch 103/150
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4364 - accuracy: 0.8800
# Epoch 104/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4339 - accuracy: 0.8800
# Epoch 105/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4313 - accuracy: 0.9000
# Epoch 106/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4287 - accuracy: 0.9100
# Epoch 107/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4260 - accuracy: 0.9100
# Epoch 108/150
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4234 - accuracy: 0.9200
# Epoch 109/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4207 - accuracy: 0.9200
# Epoch 110/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4181 - accuracy: 0.9100
# Epoch 111/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4158 - accuracy: 0.9000
# Epoch 112/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4137 - accuracy: 0.9000
# Epoch 113/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4117 - accuracy: 0.8800
# Epoch 114/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4092 - accuracy: 0.9000
# Epoch 115/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4067 - accuracy: 0.9000
# Epoch 116/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4042 - accuracy: 0.9000
# Epoch 117/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.4019 - accuracy: 0.9000
# Epoch 118/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3995 - accuracy: 0.9000
# Epoch 119/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3973 - accuracy: 0.9100
# Epoch 120/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3949 - accuracy: 0.9100
# Epoch 121/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3931 - accuracy: 0.9000
# Epoch 122/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3912 - accuracy: 0.9000
# Epoch 123/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3882 - accuracy: 0.9200
# Epoch 124/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3866 - accuracy: 0.9200
# Epoch 125/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3833 - accuracy: 0.9200
# Epoch 126/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3812 - accuracy: 0.9200
# Epoch 127/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3790 - accuracy: 0.9400
# Epoch 128/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3768 - accuracy: 0.9400
# Epoch 129/150
# 4/4 [==============================] - 0s 14ms/step - loss: 0.3744 - accuracy: 0.9400
# Epoch 130/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3721 - accuracy: 0.9400
# Epoch 131/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3702 - accuracy: 0.9500
# Epoch 132/150
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3678 - accuracy: 0.9500
# Epoch 133/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3656 - accuracy: 0.9500
# Epoch 134/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3633 - accuracy: 0.9500
# Epoch 135/150
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3613 - accuracy: 0.9500
# Epoch 136/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3592 - accuracy: 0.9400
# Epoch 137/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3574 - accuracy: 0.9300
# Epoch 138/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3554 - accuracy: 0.9300
# Epoch 139/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3533 - accuracy: 0.9400
# Epoch 140/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3511 - accuracy: 0.9500
# Epoch 141/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3495 - accuracy: 0.9500
# Epoch 142/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3471 - accuracy: 0.9500
# Epoch 143/150
# 4/4 [==============================] - 0s 11ms/step - loss: 0.3450 - accuracy: 0.9500
# Epoch 144/150
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3435 - accuracy: 0.9500
# Epoch 145/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3412 - accuracy: 0.9500
# Epoch 146/150
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3393 - accuracy: 0.9500
# Epoch 147/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3373 - accuracy: 0.9500
# Epoch 148/150
# 4/4 [==============================] - 0s 8ms/step - loss: 0.3352 - accuracy: 0.9500
# Epoch 149/150
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3334 - accuracy: 0.9500
# Epoch 150/150
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3317 - accuracy: 0.9500
# 2/2 [==============================] - 0s 7ms/step
# confusion matrix [[19  0  0]
#  [ 0 13  2]
#  [ 0  0 16]]
# classification report               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      0.87      0.93        15
#            2       0.89      1.00      0.94        16
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# loaded model test
# 2/2 [==============================] - 0s 10ms/step
# loaded confusion matrix [[19  0  0]
#  [ 0 13  2]
#  [ 0  0 16]]
# loaded classification report               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      0.87      0.93        15
#            2       0.89      1.00      0.94        16
#
#     accuracy                           0.96        50
#    macro avg       0.96      0.96      0.96        50
# weighted avg       0.96      0.96      0.96        50
